# %% [markdown]
# ### Fake News Datasets
# #### Combine Multiple Datasets
# Tweets/News from BuzzFeed, PolitiFact, GossipCop, COVID-19, Disasters
#
# Followed this link to get full data from PolitiFact and GossipCop:
# https://github.com/KaiDMML/FakeNewsNet
#
# #### Other Data Sources
# - BuzzFeed Data: https://github.com/mdani38/Fake-News-Detection
# - COVID-19 Data: https://raw.githubusercontent.com/susanli2016/NLP-with-Python/master/data/corona_fake.csv
# - Disasters Data: https://www.kaggle.com/c/nlp-getting-started/notebooks

# %%
# general packages
import pandas as pd
import numpy as np
from scipy import stats
import pickle
import re
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from scipy.stats import zscore
sns.set()

# %% [markdown]
# #### Load BuzzFeed Data

# %%
# load BuzzFeed data
buzz_fake = pd.read_csv('new_data/BuzzFeed_fake_news_content.csv', delimiter=',')
buzz_real = pd.read_csv('new_data/BuzzFeed_real_news_content.csv', delimiter=',')
print(buzz_fake.shape)
print(buzz_real.shape)

buzz_fake.head()
# Out:
# (91, 12)
# (91, 12)
#                 id                                              title  \
# 0   Fake_1-Webpage  Proof The Mainstream Media Is Manipulating The...
# 1  Fake_10-Webpage  Charity: Clinton Foundation Distributed “Water...
# 2  Fake_11-Webpage  A Hillary Clinton Administration May be Entire...
# 3  Fake_12-Webpage  Trump’s Latest Campaign Promise May Be His Mos...
# 4  Fake_13-Webpage                    Website is Down For Maintenance
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
# 1  Former President Bill Clinton and his Clinton ...
# 2  After collapsing just before trying to step in...
# 3  Donald Trump is, well, deplorable. He’s sugges...
# 4                    Website is Down For Maintenance
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# 2  http://eaglerising.com/36880/a-hillary-clinton...
# 3  http://www.addictinginfo.org/2016/09/19/trumps...
# 4  http://www.proudcons.com/clinton-foundation-ca...
#
#                                              top_img  \
# 0  http://addictinginfo.addictinginfoent.netdna-c...
# 1  http://eaglerising.com/wp-content/uploads/2016...
# 2  http://eaglerising.com/wp-content/uploads/2016...
# 3  http://addictinginfo.addictinginfoent.netdna-c...
# 4                                                NaN
#
#                        authors                        source  \
# 0              Wendy Gittleson  http://www.addictinginfo.org
# 1               View All Posts        http://eaglerising.com
# 2  View All Posts,Tony Elliott        http://eaglerising.com
# 3                  John Prager  http://www.addictinginfo.org
# 4                          NaN      http://www.proudcons.com
#
#                publish_date movies  \
# 0  {'$date': 1474243200000}    NaN
# 1  {'$date': 1474416521000}    NaN
# 2  {'$date': 1474416638000}    NaN
# 3  {'$date': 1474243200000}    NaN
# 4                       NaN    NaN
#
#                                               images  \
# 0  http://i.imgur.com/JeqZLhj.png,http://addictin...
# 1  http://constitution.com/wp-content/uploads/201...
# 2  http://constitution.com/wp-content/uploads/201...
# 3  http://i.imgur.com/JeqZLhj.png,http://2.gravat...
# 4                                                NaN
#
#                                       canonical_link  \
# 0  http://addictinginfo.com/2016/09/19/proof-the-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# 2  http://eaglerising.com/36880/a-hillary-clinton...
# 3  http://addictinginfo.com/2016/09/19/trumps-lat...
# 4                                                NaN
#
#                                            meta_data
# 0  {"publisher": "Addicting Info | The Knowledge ...
# 1  {"description": "The possibility that CHAI dis...
# 2  {"description": "Hillary Clinton may be the fi...
# 3  {"publisher": "Addicting Info | The Knowledge ...
# 4  {"og": {"url": "http://www.proudcons.com", "ty...

# %%
# set targets
buzz_fake['target'] = 'fake'
buzz_real['target'] = 'real'

# %%
# combine real/fake
buzz_full = pd.concat([buzz_fake,buzz_real], ignore_index=True)
print(buzz_full.shape)
buzz_full.head()
# Out:
# (182, 13)
#                 id                                              title  \
# 0   Fake_1-Webpage  Proof The Mainstream Media Is Manipulating The...
# 1  Fake_10-Webpage  Charity: Clinton Foundation Distributed “Water...
# 2  Fake_11-Webpage  A Hillary Clinton Administration May be Entire...
# 3  Fake_12-Webpage  Trump’s Latest Campaign Promise May Be His Mos...
# 4  Fake_13-Webpage                    Website is Down For Maintenance
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
# 1  Former President Bill Clinton and his Clinton ...
# 2  After collapsing just before trying to step in...
# 3  Donald Trump is, well, deplorable. He’s sugges...
# 4                    Website is Down For Maintenance
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# 2  http://eaglerising.com/36880/a-hillary-clinton...
# 3  http://www.addictinginfo.org/2016/09/19/trumps...
# 4  http://www.proudcons.com/clinton-foundation-ca...
#
#                                              top_img  \
# 0  http://addictinginfo.addictinginfoent.netdna-c...
# 1  http://eaglerising.com/wp-content/uploads/2016...
# 2  http://eaglerising.com/wp-content/uploads/2016...
# 3  http://addictinginfo.addictinginfoent.netdna-c...
# 4                                                NaN
#
#                        authors                        source  \
# 0              Wendy Gittleson  http://www.addictinginfo.org
# 1               View All Posts        http://eaglerising.com
# 2  View All Posts,Tony Elliott        http://eaglerising.com
# 3                  John Prager  http://www.addictinginfo.org
# 4                          NaN      http://www.proudcons.com
#
#                publish_date movies  \
# 0  {'$date': 1474243200000}    NaN
# 1  {'$date': 1474416521000}    NaN
# 2  {'$date': 1474416638000}    NaN
# 3  {'$date': 1474243200000}    NaN
# 4                       NaN    NaN
#
#                                               images  \
# 0  http://i.imgur.com/JeqZLhj.png,http://addictin...
# 1  http://constitution.com/wp-content/uploads/201...
# 2  http://constitution.com/wp-content/uploads/201...
# 3  http://i.imgur.com/JeqZLhj.png,http://2.gravat...
# 4                                                NaN
#
#                                       canonical_link  \
# 0  http://addictinginfo.com/2016/09/19/proof-the-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# 2  http://eaglerising.com/36880/a-hillary-clinton...
# 3  http://addictinginfo.com/2016/09/19/trumps-lat...
# 4                                                NaN
#
#                                            meta_data target
# 0  {"publisher": "Addicting Info | The Knowledge ...   fake
# 1  {"description": "The possibility that CHAI dis...   fake
# 2  {"description": "Hillary Clinton may be the fi...   fake
# 3  {"publisher": "Addicting Info | The Knowledge ...   fake
# 4  {"og": {"url": "http://www.proudcons.com", "ty...   fake

# %%
buzz_full['source'][0].replace('https://', '').replace('http://', '').strip()
# Out:
# 'www.addictinginfo.org'

# %%
buzz_full['source'][14]
# Out:
# nan

# %%
buzz_full['source'] = buzz_full['source'].fillna('')
buzz_full['source'][14]
# Out:
# ''

# %%
# clean source field
source_strip = lambda x: x["source"].replace('https://', '').replace('http://', '').strip()

buzz_full["source2"] = buzz_full.apply(source_strip, axis=1)
buzz_full.head()
# Out:
#                 id                                              title  \
# 0   Fake_1-Webpage  Proof The Mainstream Media Is Manipulating The...
# 1  Fake_10-Webpage  Charity: Clinton Foundation Distributed “Water...
# 2  Fake_11-Webpage  A Hillary Clinton Administration May be Entire...
# 3  Fake_12-Webpage  Trump’s Latest Campaign Promise May Be His Mos...
# 4  Fake_13-Webpage                    Website is Down For Maintenance
#
#                                                 text  \
# 0  I woke up this morning to find a variation of ...
# 1  Former President Bill Clinton and his Clinton ...
# 2  After collapsing just before trying to step in...
# 3  Donald Trump is, well, deplorable. He’s sugges...
# 4                    Website is Down For Maintenance
#
#                                                  url  \
# 0  http://www.addictinginfo.org/2016/09/19/proof-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# 2  http://eaglerising.com/36880/a-hillary-clinton...
# 3  http://www.addictinginfo.org/2016/09/19/trumps...
# 4  http://www.proudcons.com/clinton-foundation-ca...
#
#                                              top_img  \
# 0  http://addictinginfo.addictinginfoent.netdna-c...
# 1  http://eaglerising.com/wp-content/uploads/2016...
# 2  http://eaglerising.com/wp-content/uploads/2016...
# 3  http://addictinginfo.addictinginfoent.netdna-c...
# 4                                                NaN
#
#                        authors                        source  \
# 0              Wendy Gittleson  http://www.addictinginfo.org
# 1               View All Posts        http://eaglerising.com
# 2  View All Posts,Tony Elliott        http://eaglerising.com
# 3                  John Prager  http://www.addictinginfo.org
# 4                          NaN      http://www.proudcons.com
#
#                publish_date movies  \
# 0  {'$date': 1474243200000}    NaN
# 1  {'$date': 1474416521000}    NaN
# 2  {'$date': 1474416638000}    NaN
# 3  {'$date': 1474243200000}    NaN
# 4                       NaN    NaN
#
#                                               images  \
# 0  http://i.imgur.com/JeqZLhj.png,http://addictin...
# 1  http://constitution.com/wp-content/uploads/201...
# 2  http://constitution.com/wp-content/uploads/201...
# 3  http://i.imgur.com/JeqZLhj.png,http://2.gravat...
# 4                                                NaN
#
#                                       canonical_link  \
# 0  http://addictinginfo.com/2016/09/19/proof-the-...
# 1  http://eaglerising.com/36899/charity-clinton-f...
# 2  http://eaglerising.com/36880/a-hillary-clinton...
# 3  http://addictinginfo.com/2016/09/19/trumps-lat...
# 4                                                NaN
#
#                                            meta_data target  \
# 0  {"publisher": "Addicting Info | The Knowledge ...   fake
# 1  {"description": "The possibility that CHAI dis...   fake
# 2  {"description": "Hillary Clinton may be the fi...   fake
# 3  {"publisher": "Addicting Info | The Knowledge ...   fake
# 4  {"og": {"url": "http://www.proudcons.com", "ty...   fake
#
#                  source2
# 0  www.addictinginfo.org
# 1        eaglerising.com
# 2        eaglerising.com
# 3  www.addictinginfo.org
# 4      www.proudcons.com

# %%
buzz_full['id'] = 'buzzfeed'

# %%
buzz_full2 = buzz_full[['id', 'title', 'text', 'source2', 'target']]
buzz_full2 = buzz_full2.rename(columns = {'source2':'source'})
buzz_full2.head()
# Out:
#          id                                              title  \
# 0  buzzfeed  Proof The Mainstream Media Is Manipulating The...
# 1  buzzfeed  Charity: Clinton Foundation Distributed “Water...
# 2  buzzfeed  A Hillary Clinton Administration May be Entire...
# 3  buzzfeed  Trump’s Latest Campaign Promise May Be His Mos...
# 4  buzzfeed                    Website is Down For Maintenance
#
#                                                 text                 source  \
# 0  I woke up this morning to find a variation of ...  www.addictinginfo.org
# 1  Former President Bill Clinton and his Clinton ...        eaglerising.com
# 2  After collapsing just before trying to step in...        eaglerising.com
# 3  Donald Trump is, well, deplorable. He’s sugges...  www.addictinginfo.org
# 4                    Website is Down For Maintenance      www.proudcons.com
#
#   target
# 0   fake
# 1   fake
# 2   fake
# 3   fake
# 4   fake

# %% [markdown]
# #### Load COVID-19 Data

# %%
# load COVID-19 data
covid = pd.read_csv('new_data/corona_fake.csv', delimiter=',')
print(covid.shape)

covid.head()
# Out:
# (1164, 4)
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source label
# 0  coronavirusmedicalkit.com  Fake
# 1               RudyGiuliani  Fake
# 2                CharlieKirk  Fake
# 3    JoanneWrightForCongress  Fake
# 4    JoanneWrightForCongress  Fake

# %%
covid['id'] = 'covid'
covid['label'] = covid['label'].str.lower()
covid = covid.rename(columns = {'label':'target'})
covid.head()
# Out:
#                                                title  \
# 0  Due to the recent outbreak for the Coronavirus...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 text  \
# 0  You just need to add water, and the drugs and ...
# 1  Hydroxychloroquine has been shown to have a 10...
# 2  Fact: Hydroxychloroquine has been shown to hav...
# 3  The Corona virus is a man made virus created i...
# 4  Doesn’t @BillGates finance research at the Wuh...
#
#                       source target     id
# 0  coronavirusmedicalkit.com   fake  covid
# 1               RudyGiuliani   fake  covid
# 2                CharlieKirk   fake  covid
# 3    JoanneWrightForCongress   fake  covid
# 4    JoanneWrightForCongress   fake  covid

# %%
covid2 = covid[['id', 'title', 'text', 'source', 'target']]

# %%
# combine with buzzfeed data
combined = pd.concat([buzz_full2,covid2], ignore_index=True)
print(combined.shape)
combined.head()
# Out:
# (1346, 5)
#          id                                              title  \
# 0  buzzfeed  Proof The Mainstream Media Is Manipulating The...
# 1  buzzfeed  Charity: Clinton Foundation Distributed “Water...
# 2  buzzfeed  A Hillary Clinton Administration May be Entire...
# 3  buzzfeed  Trump’s Latest Campaign Promise May Be His Mos...
# 4  buzzfeed                    Website is Down For Maintenance
#
#                                                 text                 source  \
# 0  I woke up this morning to find a variation of ...  www.addictinginfo.org
# 1  Former President Bill Clinton and his Clinton ...        eaglerising.com
# 2  After collapsing just before trying to step in...        eaglerising.com
# 3  Donald Trump is, well, deplorable. He’s sugges...  www.addictinginfo.org
# 4                    Website is Down For Maintenance      www.proudcons.com
#
#   target
# 0   fake
# 1   fake
# 2   fake
# 3   fake
# 4   fake

# %% [markdown]
# #### Load Disaster Data

# %%
# load disaster data
natural = pd.read_csv('new_data/train_disaster.csv', delimiter=',')
print(natural.shape)

natural.head()
# Out:
# (7613, 5)
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
natural['id'] = 'natural_disaster'
natural['title'] = ''
natural['source'] = ''
natural['target'] = np.where(natural['target']==0, 'fake', 'real')
natural.head()
# Out:
#                  id keyword location  \
# 0  natural_disaster     NaN      NaN
# 1  natural_disaster     NaN      NaN
# 2  natural_disaster     NaN      NaN
# 3  natural_disaster     NaN      NaN
# 4  natural_disaster     NaN      NaN
#
#                                                 text target title source
# 0  Our Deeds are the Reason of this #earthquake M...   real
# 1             Forest fire near La Ronge Sask. Canada   real
# 2  All residents asked to 'shelter in place' are ...   real
# 3  13,000 people receive #wildfires evacuation or...   real
# 4  Just got sent this photo from Ruby #Alaska as ...   real

# %%
# combine with buzzfeed, covid data
natural2 = natural[['id', 'title', 'text', 'source', 'target']]
combined = pd.concat([combined,natural2], ignore_index=True)
print(combined.shape)
combined.head()
# Out:
# (8959, 5)
#          id                                              title  \
# 0  buzzfeed  Proof The Mainstream Media Is Manipulating The...
# 1  buzzfeed  Charity: Clinton Foundation Distributed “Water...
# 2  buzzfeed  A Hillary Clinton Administration May be Entire...
# 3  buzzfeed  Trump’s Latest Campaign Promise May Be His Mos...
# 4  buzzfeed                    Website is Down For Maintenance
#
#                                                 text                 source  \
# 0  I woke up this morning to find a variation of ...  www.addictinginfo.org
# 1  Former President Bill Clinton and his Clinton ...        eaglerising.com
# 2  After collapsing just before trying to step in...        eaglerising.com
# 3  Donald Trump is, well, deplorable. He’s sugges...  www.addictinginfo.org
# 4                    Website is Down For Maintenance      www.proudcons.com
#
#   target
# 0   fake
# 1   fake
# 2   fake
# 3   fake
# 4   fake

# %% [markdown]
# #### Load PolitiFact and GossipCop Data

# %%
# load PolitiFact data - partial data
polit_fake = pd.read_csv('new_data/politifact_fake.csv', delimiter=',')
polit_real = pd.read_csv('new_data/politifact_real.csv', delimiter=',')
print(polit_fake.shape)
print(polit_real.shape)

polit_fake.head()
# Out:
# (432, 4)
# (624, 4)
#                 id                                           news_url  \
# 0  politifact15014          speedtalk.com/forum/viewtopic.php?t=51650
# 1  politifact15156  politics2020.info/index.php/2018/03/13/court-o...
# 2  politifact14745  www.nscdscamps.org/blog/category/parenting/467...
# 3  politifact14355  https://howafrica.com/oscar-pistorius-attempts...
# 4  politifact15371  http://washingtonsources.org/trump-votes-for-d...
#
#                                                title  \
# 0  BREAKING: First NFL Team Declares Bankruptcy O...
# 1  Court Orders Obama To Pay $400 Million In Rest...
# 2  UPDATE: Second Roy Moore Accuser Works For Mic...
# 3         Oscar Pistorius Attempts To Commit Suicide
# 4        Trump Votes For Death Penalty For Being Gay
#
#                                            tweet_ids
# 0  937349434668498944\t937379378006282240\t937380...
# 1  972666281441878016\t972678396575559680\t972827...
# 2  929405740732870656\t929439450400264192\t929439...
# 3  886941526458347521\t887011300278194176\t887023...
# 4  915205698212040704\t915242076681506816\t915249...

# %%
# load GossipCop data - partial data
goss_fake = pd.read_csv('new_data/gossipcop_fake.csv', delimiter=',')
goss_real = pd.read_csv('new_data/gossipcop_real.csv', delimiter=',')
print(goss_fake.shape)
print(goss_real.shape)

goss_fake.head()
# Out:
# (5323, 4)
# (16817, 4)
#                      id                                           news_url  \
# 0  gossipcop-2493749932  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1  gossipcop-4580247171  hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2   gossipcop-941805037  variety.com/2017/biz/news/tax-march-donald-tru...
# 3  gossipcop-2547891536  www.dailymail.co.uk/femail/article-3499192/Do-...
# 4  gossipcop-5476631226  variety.com/2018/film/news/list-2018-oscar-nom...
#
#                                                title  \
# 0  Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1  Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2  Celebrities Join Tax March in Protest of Donal...
# 3  Cindy Crawford's daughter Kaia Gerber wears a ...
# 4      Full List of 2018 Oscar Nominations – Variety
#
#                                            tweet_ids
# 0  284329075902926848\t284332744559968256\t284335...
# 1  992895508267130880\t992897935418503169\t992899...
# 2  853359353532829696\t853359576543920128\t853359...
# 3  988821905196158981\t988824206556172288\t988825...
# 4  955792793632432131\t955795063925301249\t955798...

# %%
# load full PolitiFact data 
goss_fake2 = pd.read_csv('new_data/gossipcop_fake_full.csv', delimiter=',')
goss_real2 = pd.read_csv('new_data/gossipcop_real_full.csv', delimiter=',')
print(goss_fake2.shape)
print(goss_real2.shape)

goss_fake2.head()
# Out:
# (4900, 4)
# (14243, 4)
#    Unnamed: 0                                               text  \
# 0           0  Star magazine has released an explosive report...
# 1           1  Earlier this year, the buzz around Megyn Kelly...
# 2           2  For the first time since his involvement in a ...
# 3           3  Those heels were cute, but they didn't last lo...
# 4           4  American reality television personality and re...
#
#                       source                    id
# 0  http://www.newidea.com.au  gossipcop-1000240645
# 1    https://web.archive.org  gossipcop-1009248558
# 2   http://hollywoodlife.com  gossipcop-1012123555
# 3   http://www.x17online.com  gossipcop-1014383679
# 4    http://en.wikipedia.org  gossipcop-1014616559

# %%
# load full GossipCop data 
polit_fake2 = pd.read_csv('new_data/politifact_fake_full.csv', delimiter=',')
polit_real2 = pd.read_csv('new_data/politifact_real_full.csv', delimiter=',')
print(polit_fake2.shape)
print(polit_real2.shape)

polit_fake2.head()
# Out:
# (396, 4)
# (559, 4)
#    Unnamed: 0                                               text  \
# 0           0  Sponsored LinksRepublican attacks on transgend...
# 1           1                                                NaN
# 2           2  Mental Images“My pictures ask where does the t...
# 3           3  But it appears not all Mr Zuckerberg's own emp...
# 4           4  Fake story here…http://abcnews.com.co/donald-t...
#
#                             source               id
# 0   http://www.occupydemocrats.com  politifact11773
# 1         https://www.facebook.com  politifact13038
# 2  http://www.alison-jackson.co.uk  politifact13467
# 3               http://www.bbc.com  politifact13468
# 4                http://genius.com  politifact13475

# %%
# join GossipCop datasets
goss_fake_full = goss_fake.merge(goss_fake2, on=["id"])
goss_real_full = goss_real.merge(goss_real2, on=["id"])

print(goss_fake_full.shape)
print(goss_real_full.shape)

goss_fake_full.head()
# Out:
# (4900, 7)
# (14243, 7)
#                      id                                           news_url  \
# 0  gossipcop-2493749932  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1  gossipcop-4580247171  hollywoodlife.com/2018/05/05/paris-jackson-car...
# 2   gossipcop-941805037  variety.com/2017/biz/news/tax-march-donald-tru...
# 3  gossipcop-2547891536  www.dailymail.co.uk/femail/article-3499192/Do-...
# 4  gossipcop-5476631226  variety.com/2018/film/news/list-2018-oscar-nom...
#
#                                                title  \
# 0  Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1  Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2  Celebrities Join Tax March in Protest of Donal...
# 3  Cindy Crawford's daughter Kaia Gerber wears a ...
# 4      Full List of 2018 Oscar Nominations – Variety
#
#                                            tweet_ids  Unnamed: 0  \
# 0  284329075902926848\t284332744559968256\t284335...         796
# 1  992895508267130880\t992897935418503169\t992899...        1922
# 2  853359353532829696\t853359576543920128\t853359...        4567
# 3  988821905196158981\t988824206556172288\t988825...         829
# 4  955792793632432131\t955795063925301249\t955798...        2421
#
#                                                 text  \
# 0  Congratulations might be in order for Miley Cy...
# 1  Paris Jackson and Cara Delevingne were spotted...
# 2  Thousands are taking the streets to protest Pr...
# 3  We'd venture to say that Cindy Crawford's daug...
# 4  Oscar nominations for the 90th annual awards w...
#
#                         source
# 0  https://www.dailymail.co.uk
# 1     http://hollywoodlife.com
# 2           http://variety.com
# 3   http://www.dailymail.co.uk
# 4           http://variety.com

# %%
# join PolitFact datasets
polit_fake_full = polit_fake.merge(polit_fake2, on=["id"])
polit_real_full = polit_real.merge(polit_real2, on=["id"])

print(polit_fake_full.shape)
print(polit_real_full.shape)

polit_fake_full.head()
# Out:
# (396, 7)
# (559, 7)
#                 id                                           news_url  \
# 0  politifact15156  politics2020.info/index.php/2018/03/13/court-o...
# 1  politifact14745  www.nscdscamps.org/blog/category/parenting/467...
# 2  politifact14355  https://howafrica.com/oscar-pistorius-attempts...
# 3  politifact15371  http://washingtonsources.org/trump-votes-for-d...
# 4  politifact14404          gloria.tv/video/yRrtUtTCfPga6cq2VDJPcgQe4
#
#                                                title  \
# 0  Court Orders Obama To Pay $400 Million In Rest...
# 1  UPDATE: Second Roy Moore Accuser Works For Mic...
# 2         Oscar Pistorius Attempts To Commit Suicide
# 3        Trump Votes For Death Penalty For Being Gay
# 4  Putin says: ‘Pope Francis Is Not A Man Of God’...
#
#                                            tweet_ids  Unnamed: 0  \
# 0  972666281441878016\t972678396575559680\t972827...         292
# 1  929405740732870656\t929439450400264192\t929439...         211
# 2  886941526458347521\t887011300278194176\t887023...         140
# 3  915205698212040704\t915242076681506816\t915249...         342
# 4  893290900637483009\t893290950700802048\t893290...         149
#
#                                                 text  \
# 0  The West Texas Federal Appeals Court, operatin...
# 1  Read original article hereLiberals sure are af...
# 2  The former Paralympic athlete reportedly tried...
# 3  The Structure says states get to resolve how y...
# 4  Putin says: ‘Pope Francis Is Not A Man Of God’...
#
#                          source
# 0       https://web.archive.org
# 1     http://www.nscdscamps.org
# 2         https://howafrica.com
# 3  http://washingtonsources.org
# 4              http://gloria.tv

# %%
goss_fake_full['target'] = 'fake'
goss_fake_full[['id', 'title', 'text', 'source', 'target']].head()
# Out:
#                      id                                              title  \
# 0  gossipcop-2493749932  Did Miley Cyrus and Liam Hemsworth secretly ge...
# 1  gossipcop-4580247171  Paris Jackson & Cara Delevingne Enjoy Night Ou...
# 2   gossipcop-941805037  Celebrities Join Tax March in Protest of Donal...
# 3  gossipcop-2547891536  Cindy Crawford's daughter Kaia Gerber wears a ...
# 4  gossipcop-5476631226      Full List of 2018 Oscar Nominations – Variety
#
#                                                 text  \
# 0  Congratulations might be in order for Miley Cy...
# 1  Paris Jackson and Cara Delevingne were spotted...
# 2  Thousands are taking the streets to protest Pr...
# 3  We'd venture to say that Cindy Crawford's daug...
# 4  Oscar nominations for the 90th annual awards w...
#
#                         source target
# 0  https://www.dailymail.co.uk   fake
# 1     http://hollywoodlife.com   fake
# 2           http://variety.com   fake
# 3   http://www.dailymail.co.uk   fake
# 4           http://variety.com   fake

# %%
goss_fake_full2 = goss_fake_full[['id', 'title', 'text', 'source', 'target']]
combined = pd.concat([combined,goss_fake_full2], ignore_index=True)
print(combined.shape)
combined.head()
# Out:
# (13859, 5)
#          id                                              title  \
# 0  buzzfeed  Proof The Mainstream Media Is Manipulating The...
# 1  buzzfeed  Charity: Clinton Foundation Distributed “Water...
# 2  buzzfeed  A Hillary Clinton Administration May be Entire...
# 3  buzzfeed  Trump’s Latest Campaign Promise May Be His Mos...
# 4  buzzfeed                    Website is Down For Maintenance
#
#                                                 text                 source  \
# 0  I woke up this morning to find a variation of ...  www.addictinginfo.org
# 1  Former President Bill Clinton and his Clinton ...        eaglerising.com
# 2  After collapsing just before trying to step in...        eaglerising.com
# 3  Donald Trump is, well, deplorable. He’s sugges...  www.addictinginfo.org
# 4                    Website is Down For Maintenance      www.proudcons.com
#
#   target
# 0   fake
# 1   fake
# 2   fake
# 3   fake
# 4   fake

# %%
goss_real_full['target'] = 'real'
goss_real_full[['id', 'title', 'text', 'source', 'target']].head()
# Out:
#                  id                                              title  \
# 0  gossipcop-882573  Teen Mom Star Jenelle Evans' Wedding Dress Is ...
# 1  gossipcop-875924  Kylie Jenner refusing to discuss Tyga on Life ...
# 2  gossipcop-894416                                      Quinn Perkins
# 3  gossipcop-857248  I Tried Kim Kardashian's Butt Workout & Am For...
# 4  gossipcop-884684  Celine Dion donates concert proceeds to Vegas ...
#
#                                                 text  \
# 0  Exclusive: How Ruby’s Kente Cloth Wedding Dres...
# 1  Kylie Jenner reportedly doesn't want to talk a...
# 2  Character on American television series Scanda...
# 3  From there, you transition to the leg press ma...
# 4  (CNN) An emotional Celine Dion returned to the...
#
#                         source target
# 0       https://www.brides.com   real
# 1  https://www.dailymail.co.uk   real
# 2     https://en.wikipedia.org   real
# 3   https://www.refinery29.com   real
# 4          https://www.cnn.com   real

# %%
goss_real_full2 = goss_real_full[['id', 'title', 'text', 'source', 'target']]
combined = pd.concat([combined,goss_real_full2], ignore_index=True)
print(combined.shape)
combined.head()
# Out:
# (28102, 5)
#          id                                              title  \
# 0  buzzfeed  Proof The Mainstream Media Is Manipulating The...
# 1  buzzfeed  Charity: Clinton Foundation Distributed “Water...
# 2  buzzfeed  A Hillary Clinton Administration May be Entire...
# 3  buzzfeed  Trump’s Latest Campaign Promise May Be His Mos...
# 4  buzzfeed                    Website is Down For Maintenance
#
#                                                 text                 source  \
# 0  I woke up this morning to find a variation of ...  www.addictinginfo.org
# 1  Former President Bill Clinton and his Clinton ...        eaglerising.com
# 2  After collapsing just before trying to step in...        eaglerising.com
# 3  Donald Trump is, well, deplorable. He’s sugges...  www.addictinginfo.org
# 4                    Website is Down For Maintenance      www.proudcons.com
#
#   target
# 0   fake
# 1   fake
# 2   fake
# 3   fake
# 4   fake

# %%
polit_real_full['target'] = 'real'
polit_real_full[['id', 'title', 'text', 'source', 'target']].head()
# Out:
#                 id                                              title  \
# 0  politifact14984        National Federation of Independent Business
# 1  politifact12944                        comments in Fayetteville NC
# 2    politifact333  Romney makes pitch, hoping to close deal : Ele...
# 3   politifact4358  Democratic Leaders Say House Democrats Are Uni...
# 4    politifact779    Budget of the United States Government, FY 2008
#
#                                                 text  \
# 0  SMALL BUSINESS ECONOMIC TRENDSThe NFIB Optimis...
# 1  Need help? Contact the CQ Hotline at (800) 678...
# 2  Romney makes pitch, hoping to close dealPhoto ...
# 3  Democratic Leaders Say House Democrats Are Uni...
# 4  THE NATION’S FISCAL OUTLOOKThe President’s 200...
#
#                      source target
# 0  http://www.nfib-sbet.org   real
# 1         http://www.cq.com   real
# 2   https://web.archive.org   real
# 3   https://web.archive.org   real
# 4   https://web.archive.org   real

# %%
polit_fake_full['target'] = 'fake'
polit_fake_full[['id', 'title', 'text', 'source', 'target']].head()
# Out:
#                 id                                              title  \
# 0  politifact15156  Court Orders Obama To Pay $400 Million In Rest...
# 1  politifact14745  UPDATE: Second Roy Moore Accuser Works For Mic...
# 2  politifact14355         Oscar Pistorius Attempts To Commit Suicide
# 3  politifact15371        Trump Votes For Death Penalty For Being Gay
# 4  politifact14404  Putin says: ‘Pope Francis Is Not A Man Of God’...
#
#                                                 text  \
# 0  The West Texas Federal Appeals Court, operatin...
# 1  Read original article hereLiberals sure are af...
# 2  The former Paralympic athlete reportedly tried...
# 3  The Structure says states get to resolve how y...
# 4  Putin says: ‘Pope Francis Is Not A Man Of God’...
#
#                          source target
# 0       https://web.archive.org   fake
# 1     http://www.nscdscamps.org   fake
# 2         https://howafrica.com   fake
# 3  http://washingtonsources.org   fake
# 4              http://gloria.tv   fake

# %%
polit_real_full2 = polit_real_full[['id', 'title', 'text', 'source', 'target']]
polit_fake_full2 = polit_fake_full[['id', 'title', 'text', 'source', 'target']]
combined = pd.concat([combined,polit_real_full2], ignore_index=True)
print(combined.shape)
combined = pd.concat([combined,polit_fake_full2], ignore_index=True)
print(combined.shape)
combined.head()
# Out:
# (28661, 5)
# (29057, 5)
#          id                                              title  \
# 0  buzzfeed  Proof The Mainstream Media Is Manipulating The...
# 1  buzzfeed  Charity: Clinton Foundation Distributed “Water...
# 2  buzzfeed  A Hillary Clinton Administration May be Entire...
# 3  buzzfeed  Trump’s Latest Campaign Promise May Be His Mos...
# 4  buzzfeed                    Website is Down For Maintenance
#
#                                                 text                 source  \
# 0  I woke up this morning to find a variation of ...  www.addictinginfo.org
# 1  Former President Bill Clinton and his Clinton ...        eaglerising.com
# 2  After collapsing just before trying to step in...        eaglerising.com
# 3  Donald Trump is, well, deplorable. He’s sugges...  www.addictinginfo.org
# 4                    Website is Down For Maintenance      www.proudcons.com
#
#   target
# 0   fake
# 1   fake
# 2   fake
# 3   fake
# 4   fake

# %%
# fix target field
combined['target'].unique()
# Out:
# array(['fake', 'real', nan, 'true'], dtype=object)

# %%
combined[combined['target'].isna()]
# Out:
#         id                                              title  \
# 187  covid  CORONA UNMASKED: Chinese Intelligence Officer ...
# 197  covid  You can recover from the coronavirus disease (...
# 225  covid  Pandemic Bio-Weapon – 9. Supervirus Created by...
# 313  covid  Why the Coronavirus Seems to Hit Men Harder Th...
# 424  covid          The Coronavirus 5G Connection and Coverup
#
#                                                   text  \
# 187                                                NaN
# 197  Most of the people who catch COVID-19 can reco...
# 225                                                NaN
# 313  The coronavirus that originated in China has s...
# 424  THE STORY:The China Coronavirus COVID-19 rose ...
#
#                                                 source target
# 187                                                NaN    NaN
# 197  https://www.who.int/emergencies/diseases/novel...    NaN
# 225                                                NaN    NaN
# 313                                                NaN    NaN
# 424                       https://www.wakingtimes.com/    NaN

# %%
combined[combined['target'] == 'true'].shape
# Out:
# (584, 5)

# %%
combined['target'] = np.where(combined['target']=='true', 'real', combined['target'])
combined['target'].unique()
# Out:
# array(['fake', 'real', nan], dtype=object)

# %%
# drop where null label
combined.drop(combined[combined['target'].isna()].index, inplace = True)
combined[combined['target'].isnull()].index
# Out:
# Int64Index([], dtype='int64')

# %%
combined['target'].value_counts()
# Out:
# real    18748
# fake    10304
# Name: target, dtype: int64

# %%
combined['source'] = combined['source'].fillna('')
combined['title'] = combined['title'].fillna('')
combined['text'] = combined['text'].fillna('')

# %%
combined.isnull().sum()
# Out:
# id        0
# title     0
# text      0
# source    0
# target    0
# dtype: int64

# %%
combined.to_csv('combined_tweets.csv', index=False)
